# %%
i=7
print i
# Out:
#   File "<ipython-input-1-54b4d02c418c>", line 2
#     print i
#           ^
# SyntaxError: Missing parentheses in call to 'print'

# %%
i=7
print(i)
# Out:
# 7

# %%
7%4
# Out:
# 3

# %%
import pandas as pd
data = pd.DataFrame({'group':['a','b','c','d'],'ounces':[2,3,4,8]})
data
# Out:
#   group  ounces
# 0     a       2
# 1     b       3
# 2     c       4
# 3     d       8

# %%
git init
# Out:
#   File "<ipython-input-1-2a402a90b83b>", line 1
#     git init
#            ^
# SyntaxError: invalid syntax

# %%
list
# Out:
# list

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2694-6C3D
#
#  Directory of C:\Users\admin\Data Science
#
# 28/12/2016  11:16 AM    <DIR>          .
# 28/12/2016  11:16 AM    <DIR>          ..
# 27/12/2016  02:09 PM    <DIR>          .ipynb_checkpoints
# 28/12/2016  11:16 AM             3,930 Untitled.ipynb
#                1 File(s)          3,930 bytes
#                3 Dir(s)  92,319,731,712 bytes free

# %%
import pandas as pd
moviesDF = pd.read_csv("movies.dat",sep="::")
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   from ipykernel import kernelapp as app
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-d562279dc9a9> in <module>()
#       1 import pandas as pd
# ----> 2 moviesDF = pd.read_csv("movies.dat",sep="::")
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn.cluster import KMeans
from sklearn import datasets
import pandas as pd
data=pd.read_csv(E:\Data science\VishwaniketanDSWorkshop2016-master\K-meansGD\K_meansHW_TomMitchell_data1.csv,sep='::')
np.random.seed(5)

centers = [[1, 1], [-1, -1], [1, -1]]
iris = datasets.load_iris()
X = iris.data
y = iris.target

estimators = {'k_means_iris_3': KMeans(n_clusters=3),
              'k_means_iris_8': KMeans(n_clusters=8),
              'k_means_iris_bad_init': KMeans(n_clusters=3, n_init=1,init='random')}
# Out:
#   File "<ipython-input-7-27998ad78a8f>", line 9
#     data=pd.read_csv(E:\Data science\VishwaniketanDSWorkshop2016-master\K-meansGD\K_meansHW_TomMitchell_data1.csv,sep='::')
#                       ^
# SyntaxError: invalid syntax

# %%
cd E:\Data science\VishwaniketanDSWorkshop2016-master\K-meansGD
# Out:
#   File "<ipython-input-11-65cd98be5df6>", line 1
#     cd E:\Data science\VishwaniketanDSWorkshop2016-master\K-meansGD
#        ^
# SyntaxError: invalid syntax

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2694-6C3D
#
#  Directory of C:\Users\admin\Data Science
#
# 28/12/2016  03:01 PM    <DIR>          .
# 28/12/2016  03:01 PM    <DIR>          ..
# 27/12/2016  02:09 PM    <DIR>          .ipynb_checkpoints
# 28/12/2016  03:01 PM            16,668 Untitled.ipynb
#                1 File(s)         16,668 bytes
#                3 Dir(s)  92,289,298,432 bytes free

# %%
cd :E
# Out:
#   File "<ipython-input-13-7c4dae3d98d6>", line 1
#     cd :E
#        ^
# SyntaxError: invalid syntax

# %%
:E
# Out:
#   File "<ipython-input-14-2e045ed3b461>", line 1
#     :E
#     ^
# SyntaxError: invalid syntax

# %%
cd ../
# Out:
# C:\Users\admin

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2694-6C3D
#
#  Directory of C:\Users\admin
#
# 28/12/2016  10:20 AM    <DIR>          .
# 28/12/2016  10:20 AM    <DIR>          ..
# 27/12/2016  02:05 PM    <DIR>          .ipynb_checkpoints
# 27/12/2016  10:09 AM    <DIR>          .ipython
# 27/12/2016  12:05 PM    <DIR>          .jupyter
# 28/12/2016  11:38 AM    <DIR>          .matplotlib
# 27/12/2016  01:35 PM    <DIR>          .spyder-py3
# 26/10/2016  12:57 PM    <DIR>          Contacts
# 28/12/2016  03:05 PM    <DIR>          Data Science
# 27/12/2016  09:08 PM    <DIR>          Desktop
# 14/11/2016  08:49 PM    <DIR>          Documents
# 28/12/2016  02:48 PM    <DIR>          Downloads
# 26/10/2016  12:57 PM    <DIR>          Favorites
# 26/10/2016  12:57 PM    <DIR>          Links
# 26/10/2016  12:57 PM    <DIR>          Music
# 19/09/2011  08:25 PM            49,152 NPProt.bkp
# 19/09/2011  08:25 PM            49,152 NPProt.exe
# ...

# %%
cd "Data Science"
# Out:
# C:\Users\admin\Data Science

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2694-6C3D
#
#  Directory of C:\Users\admin\Data Science\VishwaniketanDSWorkshop2016-master
#
# 28/12/2016  03:05 PM    <DIR>          .
# 28/12/2016  03:05 PM    <DIR>          ..
# 28/12/2016  03:05 PM    <DIR>          K-meansGD
# 27/12/2016  05:29 PM            43,900 MovieLens.ipynb
# 27/12/2016  05:29 PM           171,308 movies.dat
# 27/12/2016  05:29 PM               100 README.md
# 27/12/2016  05:29 PM                39 test.ipynb
# 27/12/2016  05:29 PM               118 test2.ipynb
#                5 File(s)        215,465 bytes
#                3 Dir(s)  91,867,619,328 bytes free

# %%
cd c:\
# Out:
# C:\Users\admin\Data Science\VishwaniketanDSWorkshop2016-master

# %%
cd K-meansGD/
# Out:
# C:\Users\admin\Data Science\VishwaniketanDSWorkshop2016-master\K-meansGD

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn import datasets
from mpl_toolkits.mplot3d import Axes3D
data1=pd.read_csv("K_meansHW_TomMitchell_data1.csv",names=['I','J'])
data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')

# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data1['I'],data1['J'])
clusters_2=KMeans(n_clusters=2)


clusters_2.fit(data1)
plt.scatter(data1['I'],data1['J'],c=clusters_2.labels_.astype(np.float))
np.random.seed(5)

centers = [[1, 1], [-1, -1],[1,-1]]
iris = datasets.load_()
X = iris.data
y = iris.target

estimators = {'k_means_iris_3': KMeans(n_clusters=3),
              'k_means_iris_8': KMeans(n_clusters=8),
              'k_means_iris_bad_init': KMeans(n_clusters=3, n_init=1,
                                              init='random')}
fignum = 1
for name, est in estimators.items():
    fig = plt.figure(fignum, figsize=(4, 3))
    plt.clf()

# %%
data1
# Out:
#           I        J
# 0    2.2312  3.59710
# 1    1.8952  2.81760
# 2    2.0898  2.33910
# 3    0.5824  0.88725
# 4    1.9189  1.84270
# 5    0.5730  3.61330
# 6   -0.5504  2.23700
# 7    2.7569  3.54400
# 8    2.1627  0.05360
# 9    1.9479  0.97718
# 10   0.2723  0.33960
# 11   1.5659  1.83180
# 12   0.3472  3.33980
# 13   1.6865 -0.58640
# 14  -0.5057  1.03270
# 15   2.4422  2.23460
# 16   3.2436  0.76960
# 17   3.9216  0.65440
# 18   0.5464 -0.08070
# 19   1.8937  3.34560
# 20   0.5042  1.96970
# 21   0.4146  3.80540
# 22   1.5658 -0.23360
# 23  -0.0522  2.28800
# 24   0.1058  3.17680
# 25   2.6153  3.41450
# 26   0.0336  0.77330
# 27   0.3027  2.72840
# 28   0.6657 -0.07340
# 29   0.3838  2.56160
# ..      ...      ...
# 570 -1.6196 -1.54200
# 571 -3.6463 -0.98710
# 572 -1.7655 -4.01520
# 573 -0.3325 -1.37570
# 574 -2.5416 -1.22600
# 575 -3.9488 -0.43830
# 576 -2.9845 -1.75000
# 577  0.1509 -2.43160
# 578 -3.9940 -3.10960
# 579 -0.7830 -1.13150
# 580 -2.3657 -1.46300
# ...

# %%
estimators
# Out:
# {'k_means_iris_3': KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=3, n_init=10,
#      n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#      verbose=0),
#  'k_means_iris_8': KMeans(copy_x=True, init='k-means++', max_iter=300, n_clusters=8, n_init=10,
#      n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#      verbose=0),
#  'k_means_iris_bad_init': KMeans(copy_x=True, init='random', max_iter=300, n_clusters=3, n_init=1,
#      n_jobs=1, precompute_distances='auto', random_state=None, tol=0.0001,
#      verbose=0)}

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn.cluster import KMeans
from sklearn import datasets
import pandas as pd
engine='python'
data=pd.read_csv("K_meansHW_TomMitchell_data1.csv",sep='::')


np.random.seed(5)

centers = [[1, 1], [-1, -1]]
iris = datasets.load_()
X = iris.data
y = iris.target

estimators = {'k_means_iris_3': KMeans(n_clusters=3),
              'k_means_iris_8': KMeans(n_clusters=8),
              'k_means_iris_bad_init': KMeans(n_clusters=3, n_init=1,
                                              init='random')}
fignum = 1
for name, est in estimators.items():
    fig = plt.figure(fignum, figsize=(4, 3))
    plt.clf()
# Out:
# C:\Program Files\Anaconda3\lib\site-packages\ipykernel\__main__.py:10: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-36-7eb96887f297> in <module>()
#      14
#      15 centers = [[1, 1], [-1, -1]]
# ---> 16 iris = datasets.load_()
#      17 X = iris.data
#      18 y = iris.target
#
# AttributeError: module 'sklearn.datasets' has no attribute 'load_'

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D


from sklearn.cluster import KMeans
from sklearn import datasets
import pandas as pd
data1=pd.read_csv("K_meansHW_TomMitchell_data1.csv",sep=',')
data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')

# %%
data1
# Out:
#      2.2312   3.5971
# 0    1.8952  2.81760
# 1    2.0898  2.33910
# 2    0.5824  0.88725
# 3    1.9189  1.84270
# 4    0.5730  3.61330
# 5   -0.5504  2.23700
# 6    2.7569  3.54400
# 7    2.1627  0.05360
# 8    1.9479  0.97718
# 9    0.2723  0.33960
# 10   1.5659  1.83180
# 11   0.3472  3.33980
# 12   1.6865 -0.58640
# 13  -0.5057  1.03270
# 14   2.4422  2.23460
# 15   3.2436  0.76960
# 16   3.9216  0.65440
# 17   0.5464 -0.08070
# 18   1.8937  3.34560
# 19   0.5042  1.96970
# 20   0.4146  3.80540
# 21   1.5658 -0.23360
# 22  -0.0522  2.28800
# 23   0.1058  3.17680
# 24   2.6153  3.41450
# 25   0.0336  0.77330
# 26   0.3027  2.72840
# 27   0.6657 -0.07340
# 28   0.3838  2.56160
# 29   2.2414  0.66410
# ..      ...      ...
# 569 -1.6196 -1.54200
# 570 -3.6463 -0.98710
# 571 -1.7655 -4.01520
# 572 -0.3325 -1.37570
# 573 -2.5416 -1.22600
# 574 -3.9488 -0.43830
# 575 -2.9845 -1.75000
# 576  0.1509 -2.43160
# 577 -3.9940 -3.10960
# 578 -0.7830 -1.13150
# 579 -2.3657 -1.46300
# ...

# %%
data2
# Out:
#        -19.179    7.0317
# 0    -3.418900  23.61300
# 1    21.610000   3.55990
# 2   -19.661000  13.26400
# 3   -21.082000   7.11600
# 4    18.687000  14.54100
# 5    16.109000  13.29700
# 6     4.883800  21.85800
# 7   -16.549000 -11.34100
# 8     1.827700 -21.36400
# 9   -22.269000   1.14090
# 10    0.068116  22.66400
# 11   -1.398600 -22.66500
# 12   21.416000  -1.85020
# 13    8.525000  23.22300
# 14    3.138900  24.35500
# 15   15.859000  14.36000
# 16  -21.544000   2.28990
# 17   14.451000  14.28900
# 18  -13.181000  19.05900
# 19   -5.494400 -20.08800
# 20  -18.606000 -13.71200
# 21  -19.764000   7.49150
# 22   17.856000 -14.95500
# 23  -20.385000   5.61350
# 24  -15.016000 -19.00600
# 25   -1.490700  20.10500
# 26  -10.708000  20.53900
# 27   12.915000  16.70300
# 28    0.231630 -21.67700
# 29    8.780900 -20.25000
# ..         ...       ...
# 576   0.380430   0.45802
# 577  -1.646300   1.01290
# 578   0.234450  -2.01520
# 579   1.667500   0.62429
# 580  -0.541640   0.77398
# ...

# %%
# Out:
#        2.2312,3.5971
# 0      1.8952,2.8176
# 1      2.0898,2.3391
# 2     0.5824,0.88725
# 3      1.9189,1.8427
# 4       0.573,3.6133
# 5      -0.5504,2.237
# 6       2.7569,3.544
# 7      2.1627,0.0536
# 8     1.9479,0.97718
# 9      0.2723,0.3396
# 10     1.5659,1.8318
# 11     0.3472,3.3398
# 12    1.6865,-0.5864
# 13    -0.5057,1.0327
# 14     2.4422,2.2346
# 15     3.2436,0.7696
# 16     3.9216,0.6544
# 17    0.5464,-0.0807
# 18     1.8937,3.3456
# 19     0.5042,1.9697
# 20     0.4146,3.8054
# 21    1.5658,-0.2336
# 22     -0.0522,2.288
# 23     0.1058,3.1768
# 24     2.6153,3.4145
# 25     0.0336,0.7733
# 26     0.3027,2.7284
# 27    0.6657,-0.0734
# 28     0.3838,2.5616
# 29     2.2414,0.6641
# ..               ...
# 569   -1.6196,-1.542
# 570  -3.6463,-0.9871
# 571  -1.7655,-4.0152
# 572  -0.3325,-1.3757
# 573   -2.5416,-1.226
# 574  -3.9488,-0.4383
# 575    -2.9845,-1.75
# 576   0.1509,-2.4316
# 577   -3.994,-3.1096
# 578   -0.783,-1.1315
# 579   -2.3657,-1.463
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data1=pd.read_csv("K_meansHW_TomMitchell_data1.csv",sep=',',names='I''J')
data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')

# %%
data1
# Out:
#           I        J
# 0    2.2312  3.59710
# 1    1.8952  2.81760
# 2    2.0898  2.33910
# 3    0.5824  0.88725
# 4    1.9189  1.84270
# 5    0.5730  3.61330
# 6   -0.5504  2.23700
# 7    2.7569  3.54400
# 8    2.1627  0.05360
# 9    1.9479  0.97718
# 10   0.2723  0.33960
# 11   1.5659  1.83180
# 12   0.3472  3.33980
# 13   1.6865 -0.58640
# 14  -0.5057  1.03270
# 15   2.4422  2.23460
# 16   3.2436  0.76960
# 17   3.9216  0.65440
# 18   0.5464 -0.08070
# 19   1.8937  3.34560
# 20   0.5042  1.96970
# 21   0.4146  3.80540
# 22   1.5658 -0.23360
# 23  -0.0522  2.28800
# 24   0.1058  3.17680
# 25   2.6153  3.41450
# 26   0.0336  0.77330
# 27   0.3027  2.72840
# 28   0.6657 -0.07340
# 29   0.3838  2.56160
# ..      ...      ...
# 570 -1.6196 -1.54200
# 571 -3.6463 -0.98710
# 572 -1.7655 -4.01520
# 573 -0.3325 -1.37570
# 574 -2.5416 -1.22600
# 575 -3.9488 -0.43830
# 576 -2.9845 -1.75000
# 577  0.1509 -2.43160
# 578 -3.9940 -3.10960
# 579 -0.7830 -1.13150
# 580 -2.3657 -1.46300
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import datasets
import pandas as pd
data1=pd.read_csv("K_meansHW_TomMitchell_data1.csv",sep=',',names=['I','J'])
#data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')
data1
# Out:
#           I        J
# 0    2.2312  3.59710
# 1    1.8952  2.81760
# 2    2.0898  2.33910
# 3    0.5824  0.88725
# 4    1.9189  1.84270
# 5    0.5730  3.61330
# 6   -0.5504  2.23700
# 7    2.7569  3.54400
# 8    2.1627  0.05360
# 9    1.9479  0.97718
# 10   0.2723  0.33960
# 11   1.5659  1.83180
# 12   0.3472  3.33980
# 13   1.6865 -0.58640
# 14  -0.5057  1.03270
# 15   2.4422  2.23460
# 16   3.2436  0.76960
# 17   3.9216  0.65440
# 18   0.5464 -0.08070
# 19   1.8937  3.34560
# 20   0.5042  1.96970
# 21   0.4146  3.80540
# 22   1.5658 -0.23360
# 23  -0.0522  2.28800
# 24   0.1058  3.17680
# 25   2.6153  3.41450
# 26   0.0336  0.77330
# 27   0.3027  2.72840
# 28   0.6657 -0.07340
# 29   0.3838  2.56160
# ..      ...      ...
# 570 -1.6196 -1.54200
# 571 -3.6463 -0.98710
# 572 -1.7655 -4.01520
# 573 -0.3325 -1.37570
# 574 -2.5416 -1.22600
# 575 -3.9488 -0.43830
# 576 -2.9845 -1.75000
# 577  0.1509 -2.43160
# 578 -3.9940 -3.10960
# 579 -0.7830 -1.13150
# 580 -2.3657 -1.46300
# ...

# %%
data1
# Out:
#           I        J
# 0    2.2312  3.59710
# 1    1.8952  2.81760
# 2    2.0898  2.33910
# 3    0.5824  0.88725
# 4    1.9189  1.84270
# 5    0.5730  3.61330
# 6   -0.5504  2.23700
# 7    2.7569  3.54400
# 8    2.1627  0.05360
# 9    1.9479  0.97718
# 10   0.2723  0.33960
# 11   1.5659  1.83180
# 12   0.3472  3.33980
# 13   1.6865 -0.58640
# 14  -0.5057  1.03270
# 15   2.4422  2.23460
# 16   3.2436  0.76960
# 17   3.9216  0.65440
# 18   0.5464 -0.08070
# 19   1.8937  3.34560
# 20   0.5042  1.96970
# 21   0.4146  3.80540
# 22   1.5658 -0.23360
# 23  -0.0522  2.28800
# 24   0.1058  3.17680
# 25   2.6153  3.41450
# 26   0.0336  0.77330
# 27   0.3027  2.72840
# 28   0.6657 -0.07340
# 29   0.3838  2.56160
# ..      ...      ...
# 570 -1.6196 -1.54200
# 571 -3.6463 -0.98710
# 572 -1.7655 -4.01520
# 573 -0.3325 -1.37570
# 574 -2.5416 -1.22600
# 575 -3.9488 -0.43830
# 576 -2.9845 -1.75000
# 577  0.1509 -2.43160
# 578 -3.9940 -3.10960
# 579 -0.7830 -1.13150
# 580 -2.3657 -1.46300
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data1['I'],data1['J'])

# %%
clusters_2=KMeans(n_clusters=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-98263d60306e> in <module>()
# ----> 1 clusters_2=KMeans(n_clusters=2)
#
# NameError: name 'KMeans' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
data1=pd.read_csv("K_meansHW_TomMitchell_data1.csv",names=['I','J'])
data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')

# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data1['I'],data1['J'])
clusters_2=KMeans(n_clusters=2)


clusters_2.fit(data1)
plt.scatter(data1['I'],data1['J'],c=clusters_2.labels_.astype(np.float))
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-5d051feacde5> in <module>()
#       2 import matplotlib.pyplot as plt
#       3 import pandas as pd
# ----> 4 data1=pd.read_csv("K_meansHW_TomMitchell_data1.csv",names=['I','J'])
#       5 data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')
#       6
#
# ...

# %%
ls
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2694-6C3D
#
#  Directory of C:\Users\admin\Data Science\VishwaniketanDSWorkshop2016-master\K-meansGD
#
# 28/12/2016  03:05 PM    <DIR>          .
# 28/12/2016  03:05 PM    <DIR>          ..
# 27/12/2016  05:29 PM             1,899 girls_age_weight_height_2_8.csv
# 27/12/2016  05:29 PM               158 girls_test.csv
# 27/12/2016  05:29 PM             1,134 girls_train.csv
# 27/12/2016  05:29 PM             9,521 K_meansHW_TomMitchell_data1.csv
# 27/12/2016  05:29 PM             9,956 K_meansHW_TomMitchell_data2.csv
# 27/12/2016  05:29 PM                 1 test.txt
#                6 File(s)         22,669 bytes
#                2 Dir(s)  91,865,743,360 bytes free

# %%
c../
# Out:
#   File "<ipython-input-21-d88219bd8164>", line 1
#     c../
#       ^
# SyntaxError: invalid syntax

# %%
cd..\
# Out:
#   File "<ipython-input-22-d7509b811d2d>", line 1
#     cd..
#        ^
# SyntaxError: invalid syntax

# %%
cd..
# Out:
#   File "<ipython-input-23-d7509b811d2d>", line 1
#     cd..
#        ^
# SyntaxError: invalid syntax

# %%
cd../
# Out:
#   File "<ipython-input-24-5de25b031d06>", line 1
#     cd../
#        ^
# SyntaxError: invalid syntax

# %%
cd ..\
# Out:
# C:\Users\admin\Data Science\VishwaniketanDSWorkshop2016-master

# %%
cd ..\
# Out:
# C:\Users\admin\Data Science

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn import datasets
from mpl_toolkits.mplot3d import Axes3D
data=pd.read_csv("ex2data1.csv",sep=',')
#data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')
data
# Out:
#         Exam1      Exam2  Accepted
# 0   34.623660  78.024693         0
# 1   30.286711  43.894998         0
# 2   35.847409  72.902198         0
# 3   60.182599  86.308552         1
# 4   79.032736  75.344376         1
# 5   45.083277  56.316372         0
# 6   61.106665  96.511426         1
# 7   75.024746  46.554014         1
# 8   76.098787  87.420570         1
# 9   84.432820  43.533393         1
# 10  95.861555  38.225278         0
# 11  75.013658  30.603263         0
# 12  82.307053  76.481963         1
# 13  69.364589  97.718692         1
# 14  39.538339  76.036811         0
# 15  53.971052  89.207350         1
# 16  69.070144  52.740470         1
# 17  67.946855  46.678574         0
# 18  70.661510  92.927138         1
# 19  76.978784  47.575964         1
# 20  67.372028  42.838438         0
# 21  89.676776  65.799366         1
# 22  50.534788  48.855812         0
# 23  34.212061  44.209529         0
# 24  77.924091  68.972360         1
# 25  62.271014  69.954458         1
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.scatter(data1,data1)
clusters_2=KMeans(n_clusters=2)


clusters_2.fit(data1)
plt.scatter(data1['I'],data1['J'],c=clusters_2.labels_.astype(np.float))
np.random.seed(5)

centers = [[1, 1], [-1, -1],[1,-1]]
iris = datasets.load_()
X = iris.data
y = iris.target

estimators = {'k_means_iris_3': KMeans(n_clusters=3),
              'k_means_iris_8': KMeans(n_clusters=8),
              'k_means_iris_bad_init': KMeans(n_clusters=3, n_init=1,
                                              init='random')}
fignum = 1
for name, est in estimators.items():
    fig = plt.figure(fignum, figsize=(4, 3))
    plt.clf()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-5f18ea511a0d> in <module>()
#       1 get_ipython().magic('matplotlib inline')
#       2 import matplotlib.pyplot as plt
# ----> 3 plt.scatter(data1,data1)
#       4 clusters_2=KMeans(n_clusters=2)
#       5
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, hold, data, **kwargs)
#    3256                          vmin=vmin, vmax=vmax, alpha=alpha,
#    3257                          linewidths=linewidths, verts=verts,
# -> 3258                          edgecolors=edgecolors, data=data, **kwargs)
#    3259     finally:
#    3260         ax.hold(washold)
#
# C:\Program Files\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, *args, **kwargs)
# ...

# %%
#import numpy as np
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
from sklearn import datasets
from mpl_toolits.mplot3d import Axes3D
data=pd.read_csv("ex2data1.csv",sep=',')
#data2=pd.read_csv("K_meansHW_TomMitchell_data2.csv",sep=',')
data

import matplotlib.pyplot as plt
import pandas as pd

lr1=pd.read_csv("ex2data1.csv")

lr1.head()
fig=plt.figure()
ax = fig.add_subplot(1,1,1)
ax.scatter(lr1['Exam1'],lr1['Exam2'],lr1['Accepted'],color=['Red','Green','Blue'])
plt.title('Exam1 & 2')
plt.xlabel('Exam1')
plt.ylabel('Exam2')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D
centers = [[1, 1], [-1, -1], [1, -1]]
X = lr1['Exam1'].data
y = lr1['Exam1'].target
np.random.seed(5)
fig=plt.figure()
 ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
        
    
ax.scatter(X[:, 3], X[:, 0], X[:, 2])#, c=labels.astype(np.float))

plt.show()
# Out:
#   File "<ipython-input-33-d48b2d0cff79>", line 7
#     ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)
#     ^
# IndentationError: unexpected indent
